# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.fft import fft

# %%
nnC1_00 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase1_xD_00.csv'))
nnC1_16 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase1_xD_16.csv'))
nnC1_30 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase1_xD_30.csv'))
nnC1_50 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase1_xD_50.csv'))
nnC1_70 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase1_xD_70.csv'))

nnC2_00 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase2_xD_00.csv'))
nnC2_16 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase2_xD_16.csv'))
nnC2_30 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase2_xD_30.csv'))
nnC2_50 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase2_xD_50.csv'))
nnC2_70 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase2_xD_70.csv'))

nnC3_00 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase3_xD_00.csv'))
nnC3_16 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase3_xD_16.csv'))
nnC3_30 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase3_xD_30.csv'))
nnC3_50 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase3_xD_50.csv'))
nnC3_70 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase3_xD_70.csv'))

# %%
dynC1_00 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase1_xD_00.csv'))
dynC1_16 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase1_xD_16.csv'))
dynC1_30 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase1_xD_30.csv'))
dynC1_50 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase1_xD_50.csv'))
dynC1_70 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase1_xD_70.csv'))

dynC2_00 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase2_xD_00.csv'))
dynC2_16 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase2_xD_16.csv'))
dynC2_30 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase2_xD_30.csv'))
dynC2_50 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase2_xD_50.csv'))
dynC2_70 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase2_xD_70.csv'))

dynC3_00 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase3_xD_00.csv'))
dynC3_16 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase3_xD_16.csv'))
dynC3_30 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase3_xD_30.csv'))
dynC3_50 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase3_xD_50.csv'))
dynC3_70 = pd.DataFrame(data=pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase3_xD_70.csv'))

# %%
def crossVelPlot(d00, d16, d30, d50, d70, n00, n16, n30, n50, n70):
    plt.plot(n00.arc_length-4.0, n00.UMean_X, 'r--', linewidth=0.95)
    plt.plot(d00.arc_length-4.0, d00.UMean_X, 'b-', linewidth=0.95)
    plt.plot(n16.arc_length-4.0, n16.UMean_X + .5, 'r--', linewidth=0.95)
    plt.plot(d16.arc_length-4.0, d16.UMean_X + .5, 'b-', linewidth=0.95)
    plt.plot(n30.arc_length-4.0, n30.UMean_X + .85, 'r--', linewidth=0.95)
    plt.plot(d30.arc_length-4.0, d30.UMean_X + .85, 'b-', linewidth=0.95)
    plt.plot(n50.arc_length-4.0, n50.UMean_X + 1, 'r--', linewidth=0.95)
    plt.plot(d50.arc_length-4.0, d50.UMean_X + 1, 'b-', linewidth=0.95)
    plt.plot(n70.arc_length-4.0, n70.UMean_X + 1.15, 'r--', linewidth=0.95)
    plt.plot(d70.arc_length-4.0, d70.UMean_X + 1.15, 'b-', linewidth=0.95)

    plt.legend(['NN', 'CFD'])
    plt.xlabel(r'$y/D$')
    plt.ylabel(r'$U_x$')
    plt.tick_params(axis='y', which='both',
                    left=False, right=False, labelleft=False)
    plt.text(2.55, 0.92, r'$x/D = 0.0$')
    plt.text(2.55, 1.43, r'$x/D = 1.6$')
    plt.text(2.55, 1.77, r'$x/D = 3.0$')
    plt.text(2.55, 1.92, r'$x/D = 5.0$')
    plt.text(2.55, 2.07, r'$x/D = 7.0$')

# %%
crossVelPlot(dynC1_00, dynC1_16, dynC1_30, dynC1_50, dynC1_70,
             nnC1_00, nnC1_16, nnC1_30, nnC1_50, nnC1_70)

# %%
crossVelPlot(dynC2_00, dynC2_16, dynC2_30, dynC2_50, dynC2_70,
             nnC2_00, nnC2_16, nnC2_30, nnC2_50, nnC2_70)

# %%
crossVelPlot(dynC3_00, dynC3_16, dynC3_30, dynC3_50, dynC3_70,
             nnC3_00, nnC3_16, nnC3_30, nnC3_50, nnC3_70)

# %%
def energyCal(var):
    n = len(var)
    var_hat = fft(var - np.mean(var))
    var_hat = var_hat[0:int(n/2+1)]
    s = 2*np.pi/n
    f = np.arange(0, np.pi, s)
    e = 1/(2*np.pi*n) * np.abs(var_hat)**2.0
     
    return f, e

def engPlot(nnVar, dynVar, title, ylab):
    nnf, nne = energyCal(nnVar)
    dynf, dyne = energyCal(dynVar)
    plt.loglog(nnf,10**(-2.3) * nnf**(-3), 'k--')
    plt.loglog(dynf,dyne)
    plt.loglog(nnf,nne)
    plt.ylim([1e-13, 1e4])
    plt.legend(['$k^{-5/3}$', 'CFD', 'NN'])
    plt.title(title)
    plt.xlabel(r'freq')
    plt.ylabel(ylab)

# %%
engPlot(nnC1_00.U_X.values, dynC1_00.U_X.values, r'$x/D=0.0$', r'$U_x$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/2042987880.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC1_16.U_X.values, dynC1_16.U_X.values, r'$x/D=1.6$', r'$U_x$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/2042987880.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC1_30.U_X.values, dynC1_30.U_X.values, r'$x/D=3.0$', r'$U_x$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/2042987880.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC1_50.U_X.values, dynC1_50.U_X.values, r'$x/D=5.0$', r'$U_x$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/2042987880.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC1_00.Cs.values, dynC1_00.Cs.values, r'$x/D=0.0$', r'$C_s$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/2042987880.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC1_16.Cs.values, dynC1_16.Cs.values, r'$x/D=1.6$', r'$C_s$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/2042987880.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC1_30.Cs.values, dynC1_30.Cs.values, r'$x/D=3.0$', r'$C_s$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/2042987880.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC1_00.vortexStretching.values, dynC1_00.vortexStretching.values, r'$x/D=0.0$', r'$\omega_i \omega_j \mathcal{S}_{ij}$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/2574477321.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-2.3) * nnf**(-3), 'k--')

# %%
nnC1_00.columns
# Out:
# Index(['arc_length', 'Cs', 'UMean_Magnitude', 'UMean_X', 'UMean_Y', 'UMean_Z',
#        'UPrime2Mean_Magnitude', 'UPrime2Mean_XX', 'UPrime2Mean_XY',
#        'UPrime2Mean_XZ', 'UPrime2Mean_YY', 'UPrime2Mean_YZ', 'UPrime2Mean_ZZ',
#        'U_Magnitude', 'U_X', 'U_Y', 'U_Z', 'epsilon', 'k', 'nut', 'skewness',
#        'strainSeflAmp', 'vortexStretching'],
#       dtype='object')

# %%
engPlot(nnC1_16.vortexStretching.values, dynC1_16.vortexStretching.values, r'$x/D=1.6$', r'$\omega_i \omega_j \mathcal{S}_{ij}$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/2574477321.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-2.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC1_30.vortexStretching.values, dynC1_30.vortexStretching.values, r'$x/D=3.0$', r'$\omega_i \omega_j \mathcal{S}_{ij}$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/3815392455.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-2.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC2_00.Cs.values, dynC2_00.Cs.values, r'$x/D=0.0$', r'$C_s$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/2625454770.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC2_16.Cs.values, dynC2_16.Cs.values, r'$x/D=1.6$', r'$C_s$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/925390896.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC2_30.Cs.values, dynC2_30.Cs.values, r'$x/D=3.0$', r'$C_s$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/925390896.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC2_00.vortexStretching.values, dynC2_00.vortexStretching.values, r'$x/D=0.0$', r'$\omega_i \omega_j \mathcal{S}_{ij}$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/1021604171.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-2.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC2_16.vortexStretching.values, dynC2_16.vortexStretching.values, r'$x/D=1.6$', r'$\omega_i \omega_j \mathcal{S}_{ij}$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/1021604171.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-2.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC2_30.vortexStretching.values, dynC2_30.vortexStretching.values, r'$x/D=3.0$', r'$\omega_i \omega_j \mathcal{S}_{ij}$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/1021604171.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-2.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC3_00.Cs.values, dynC3_00.Cs.values, r'$x/D=0.0$', r'$C_s$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/925390896.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC3_16.Cs.values, dynC3_16.Cs.values, r'$x/D=1.6$', r'$C_s$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/925390896.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC3_30.Cs.values, dynC3_30.Cs.values, r'$x/D=3.0$', r'$C_s$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/925390896.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-4.3) * nnf**(-3), 'k--')

# %%
engPlot(nnC3_00.vortexStretching.values, dynC3_00.vortexStretching.values, r'$x/D=0.0$', r'$\omega_i \omega_j \mathcal{S}_{ij}$')
# Out:
# /var/folders/jp/k3gpcf812c14k7g8shyln3zh0000gn/T/ipykernel_11803/1021604171.py:14: RuntimeWarning: divide by zero encountered in power
#   plt.loglog(nnf,10**(-2.3) * nnf**(-3), 'k--')
