# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
nnC1 = pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase1_Streamwise.csv')
nnC2 = pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase2_Streamwise.csv')
nnC3 = pd.read_csv('/Users/ali/Desktop/JournalPaper3/nnSGSCase3_Streamwise.csv')

dynC1 = pd.read_csv('/Users/ali/Desktop/JournalPaper3/dynCase1_Streamwise.csv')

# %%
plt.plot(nnC1['arc_length'], nnC1['UMean_X'])
plt.plot(dynC1['arc_length'], dynC1['UMean_X'])
